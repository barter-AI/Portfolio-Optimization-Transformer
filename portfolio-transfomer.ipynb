# %%
# !conda env create -f ../input/pt-loss-penalised/Portfolio-Optimization-Transformer/environment.yaml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# cryptography-38.0.4  | 1.4 MB    | ##################################### | 100%
# gflags-2.2.2         | 126 KB    | ##################################### | 100%
# chardet-4.0.0        | 194 KB    | ##################################### | 100%
# zlib-1.2.13          | 103 KB    | ##################################### | 100%
# re2-2022.04.01       | 210 KB    | ##################################### | 100%
# libcurl-7.87.0       | 373 KB    | ##################################### | 100%
# libgomp-11.2.0       | 474 KB    | ##################################### | 100%
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
# jpeg-9e              | 240 KB    | ##################################### | 100%
# ...

# %%
# !conda activate portfolio
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# !python ../input/pt-loss-penalised/Portfolio-Optimization-Transformer/main.py
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/distributed/distributed_c10d.py:263: UserWarning: torch.distributed.reduce_op is deprecated, please use torch.distributed.ReduceOp instead
#   "torch.distributed.reduce_op is deprecated, please use "
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
